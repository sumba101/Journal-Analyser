# %%
import pickle

# %%
f = open("Anand.pkl", 'rb')

# %%
a = pickle.load(f)

# %%
a
# Out:
# [{'datetime': datetime.datetime(2022, 5, 10, 14, 39, 47, 17217),
#   'entry': 'फ्लाइट में बहुत मज़ा आया. कैब वाले ने फिर से कैंसिल कर दिया. मुझे बहुत गुस्सा आ रहा है.'},
#  {'datetime': datetime.datetime(2022, 5, 13, 12, 36, 47, 911314),
#   'entry': 'आज मैं पूरे दिन व्यस्त रहा। अपना होमवर्क पूरा किया। विद्यालय में एक भाषण प्रतियोगिता थी, उसमें भाग लिया। आज भी भाषण प्रतियोगिता का विषय था - परिश्रम का महत्व। मैंने बताया - सफलता प्राप्त करने का सबसे महत्वपूर्ण साधन है - परिश्रम। जीवन की इच्छाओं और मनोकामनाओं को पूरा करना है तो परिश्रम ज़रूरी है। जो व्यक्ति परिश्रम नहीं करता, उसका जीवन बेकार हो जाता है। वह आलसी और रोगी हो जाता है।'},
#  {'datetime': datetime.datetime(2022, 5, 13, 12, 37, 13, 327189),
# ...

# %%
a[1]
# Out:
# {'datetime': datetime.datetime(2022, 5, 13, 12, 36, 47, 911314),
#  'entry': 'आज मैं पूरे दिन व्यस्त रहा। अपना होमवर्क पूरा किया। विद्यालय में एक भाषण प्रतियोगिता थी, उसमें भाग लिया। आज भी भाषण प्रतियोगिता का विषय था - परिश्रम का महत्व। मैंने बताया - सफलता प्राप्त करने का सबसे महत्वपूर्ण साधन है - परिश्रम। जीवन की इच्छाओं और मनोकामनाओं को पूरा करना है तो परिश्रम ज़रूरी है। जो व्यक्ति परिश्रम नहीं करता, उसका जीवन बेकार हो जाता है। वह आलसी और रोगी हो जाता है।'}

# %%
import pandas

# %%
b = [{'datetime': datetime.datetime(2022, 5, 10, 14, 39, 47, 17217),
  'entry': 'फ्लाइट में बहुत मज़ा आया. कैब वाले ने फिर से कैंसिल कर दिया. मुझे बहुत गुस्सा आ रहा है.'},
 {'datetime': datetime.datetime(2022, 5, 11, 12, 36, 47, 911314),
  'entry': 'आज मैं पूरे दिन व्यस्त रहा। अपना होमवर्क पूरा किया। विद्यालय में एक भाषण प्रतियोगिता थी, उसमें भाग लिया। आज भी भाषण प्रतियोगिता का विषय था - परिश्रम का महत्व। मैंने बताया - सफलता प्राप्त करने का सबसे महत्वपूर्ण साधन है - परिश्रम। जीवन की इच्छाओं और मनोकामनाओं को पूरा करना है तो परिश्रम ज़रूरी है। जो व्यक्ति परिश्रम नहीं करता, उसका जीवन बेकार हो जाता है। वह आलसी और रोगी हो जाता है।'},
 {'datetime': datetime.datetime(2022, 5, 14, 12, 36, 47, 911314),
  'entry': 'आज मैं पूरे दिन व्यस्त रहा। अपना होमवर्क पूरा किया। विद्यालय में एक भाषण प्रतियोगिता थी, उसमें भाग लिया। आज भी भाषण प्रतियोगिता का विषय था - परिश्रम का महत्व। मैंने बताया - सफलता प्राप्त करने का सबसे महत्वपूर्ण साधन है - परिश्रम। जीवन की इच्छाओं और मनोकामनाओं को पूरा करना है तो परिश्रम ज़रूरी है। जो व्यक्ति परिश्रम नहीं करता, उसका जीवन बेकार हो जाता है। वह आलसी और रोगी हो जाता है।'},
 {'datetime': datetime.datetime(2022, 5, 15, 12, 36, 47, 911314),
  'entry': 'आज मैं पूरे दिन व्यस्त रहा। अपना होमवर्क पूरा किया। विद्यालय में एक भाषण प्रतियोगिता थी, उसमें भाग लिया। आज भी भाषण प्रतियोगिता का विषय था - परिश्रम का महत्व। मैंने बताया - सफलता प्राप्त करने का सबसे महत्वपूर्ण साधन है - परिश्रम। जीवन की इच्छाओं और मनोकामनाओं को पूरा करना है तो परिश्रम ज़रूरी है। जो व्यक्ति परिश्रम नहीं करता, उसका जीवन बेकार हो जाता है। वह आलसी और रोगी हो जाता है।'},
 {'datetime': datetime.datetime(2022, 5, 16, 12, 36, 47, 911314),
  'entry': 'आज मैं पूरे दिन व्यस्त रहा। अपना होमवर्क पूरा किया। विद्यालय में एक भाषण प्रतियोगिता थी, उसमें भाग लिया। आज भी भाषण प्रतियोगिता का विषय था - परिश्रम का महत्व। मैंने बताया - सफलता प्राप्त करने का सबसे महत्वपूर्ण साधन है - परिश्रम। जीवन की इच्छाओं और मनोकामनाओं को पूरा करना है तो परिश्रम ज़रूरी है। जो व्यक्ति परिश्रम नहीं करता, उसका जीवन बेकार हो जाता है। वह आलसी और रोगी हो जाता है।'},
 {'datetime': datetime.datetime(2022, 5, 17, 12, 36, 47, 911314),
  'entry': 'आज मैं पूरे दिन व्यस्त रहा। अपना होमवर्क पूरा किया। विद्यालय में एक भाषण प्रतियोगिता थी, उसमें भाग लिया। आज भी भाषण प्रतियोगिता का विषय था - परिश्रम का महत्व। मैंने बताया - सफलता प्राप्त करने का सबसे महत्वपूर्ण साधन है - परिश्रम। जीवन की इच्छाओं और मनोकामनाओं को पूरा करना है तो परिश्रम ज़रूरी है। जो व्यक्ति परिश्रम नहीं करता, उसका जीवन बेकार हो जाता है। वह आलसी और रोगी हो जाता है।'},
 {'datetime': datetime.datetime(2022, 5, 18, 12, 36, 47, 911314),
  'entry': 'आज मैं पूरे दिन व्यस्त रहा। अपना होमवर्क पूरा किया। विद्यालय में एक भाषण प्रतियोगिता थी, उसमें भाग लिया। आज भी भाषण प्रतियोगिता का विषय था - परिश्रम का महत्व। मैंने बताया - सफलता प्राप्त करने का सबसे महत्वपूर्ण साधन है - परिश्रम। जीवन की इच्छाओं और मनोकामनाओं को पूरा करना है तो परिश्रम ज़रूरी है। जो व्यक्ति परिश्रम नहीं करता, उसका जीवन बेकार हो जाता है। वह आलसी और रोगी हो जाता है।'},
 {'datetime': datetime.datetime(2022, 5, 19, 12, 36, 47, 911314),
  'entry': 'आज मैं पूरे दिन व्यस्त रहा। अपना होमवर्क पूरा किया। विद्यालय में एक भाषण प्रतियोगिता थी, उसमें भाग लिया। आज भी भाषण प्रतियोगिता का विषय था - परिश्रम का महत्व। मैंने बताया - सफलता प्राप्त करने का सबसे महत्वपूर्ण साधन है - परिश्रम। जीवन की इच्छाओं और मनोकामनाओं को पूरा करना है तो परिश्रम ज़रूरी है। जो व्यक्ति परिश्रम नहीं करता, उसका जीवन बेकार हो जाता है। वह आलसी और रोगी हो जाता है।'},
 
 {'datetime': datetime.datetime(2022, 5, 12, 12, 37, 13, 327189),
  'entry': 'कल की तरह आज भी पूरे दिन बिजली नहीं आई। शाम को सात बजे बिजली ने दर्शन दिए, लेकिन 10 मिनट बाद ही चली गई। इनवर्टर की कम रोशनी में डायरी लिख रहा हूं। कई दिन से बिजली की आँख-मिचैली चल रही थी। बार-बार आती थी और जाती थी किंतु कल से तो कई-कई घंटों तक बिजली न आने से जन-जीवन ठप्प हो गया है। बिजली नहीं तो पानी नहीं। बरसात की उमस में बेहाल तन, पसीने से तर-बतर शरीर, कैसे कटेगी रात। हमारे विद्यालय में तो जरनेटर लगा हुआ है लेकिन वह भी कितना काम करेगा।'},
 {'datetime': datetime.datetime(2022, 5, 13, 12, 37, 26, 978096),
  'entry': 'घर पर कंप्यूटर और टेलीविजन बंद पड़े हैं। इतना हुआ कि पहले हम सब लोग अलग-अलग कमरों में बैठकर अपने-अपने काम में व्यस्त रहते थे। आपस में मिलने का समय कम ही मिलता था। अब सब लोग एक ही कमरे में एक साथ बैठकर खाना खाते हैं, गपशप करते हैं और बिजली के साथ-साथ नगर और देश की घटनाओं पर चर्चा करते हैं।'}]

# %%
import datetime

# %%
g = open("newAnand.pkl", "wb")

# %%
pickle.dump(b, g)

# %%
g.close()

# %%
h = open("newAnand.pkl", "rb")

# %%
pickle.load(h)
# Out:
# [{'datetime': datetime.datetime(2022, 5, 10, 14, 39, 47, 17217),
#   'entry': 'फ्लाइट में बहुत मज़ा आया. कैब वाले ने फिर से कैंसिल कर दिया. मुझे बहुत गुस्सा आ रहा है.'},
#  {'datetime': datetime.datetime(2022, 5, 11, 12, 36, 47, 911314),
#   'entry': 'आज मैं पूरे दिन व्यस्त रहा। अपना होमवर्क पूरा किया। विद्यालय में एक भाषण प्रतियोगिता थी, उसमें भाग लिया। आज भी भाषण प्रतियोगिता का विषय था - परिश्रम का महत्व। मैंने बताया - सफलता प्राप्त करने का सबसे महत्वपूर्ण साधन है - परिश्रम। जीवन की इच्छाओं और मनोकामनाओं को पूरा करना है तो परिश्रम ज़रूरी है। जो व्यक्ति परिश्रम नहीं करता, उसका जीवन बेकार हो जाता है। वह आलसी और रोगी हो जाता है।'},
#  {'datetime': datetime.datetime(2022, 5, 14, 12, 36, 47, 911314),
# ...
